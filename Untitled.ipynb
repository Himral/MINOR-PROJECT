# %%
import pandas as pd
csv_file_path = 'amazon400k.csv'

# Use pandas to read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0      reviewerID        asin  \
# 0             381179      381179  A2AVL6ZIA1RBWY  B001415ENM
# 1            1308662     1308662  A3DA4EN3AQ3HG4  B007KZQM9Q
# 2            1383310     1383310  A2G9AHPE4PUJMU  B008BSIITI
# 3             827134      827134  A2T3YE384I0PIR  B003USYPX2
# 4             264994      264994  A1AB0900EJYQFN  B000MKWM2W
# ...              ...         ...             ...         ...
# 399995        453805      453805  A187MJW4Y5HVEK  B001ESDOP0
# 399996        752964      752964  A1U62JQDUBJJBO  B003D8M4U0
# 399997       1031064     1031064  A1H0W7S2H5HC04  B004UHD9JI
# 399998       1494618     1494618  A13ZRMBX44LJ0S  B009UEAZ84
# 399999        723006      723006  A34VRVI4CSI5RQ  B00372YKMM
#
#                            reviewerName   helpful  \
# 0                             Von Welch    [1, 1]
# 1                      K.K "Power User"  [14, 16]
# 2                               GolmaaL    [0, 0]
# ...

# %%
df_sentiment = df[["reviewText","overall","summary"]]

# %%
df_sentiment
# Out:
#                                                reviewText  overall  \
# 0       After reading all the reviews, and the forum, ...        4
# 1       Update 6/18/2013:After 3 months of use, I have...        3
# 2       Fits great. Just take your time to install, an...        5
# 3       I purchased this for use on a Rebel T5i. I spe...        5
# 4       The V320 is a nice wireless laptop mouse that ...        4
# ...                                                   ...      ...
# 399995  Works for Windows 7(Just install the latest dr...        4
# 399996  came with a partial charge. ran that down and ...        4
# 399997  I am a 'be ready' person.for the price, it is ...        5
# 399998  i bought this because my sound sstem is quit l...        5
# 399999  Working in a noisy computer lab I use active n...        4
#
#                                                   summary
# 0       Good DTV (HD?) tuner, works with Comcast, sets...
# ...
